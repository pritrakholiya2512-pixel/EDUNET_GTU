# %% [markdown]
# <a href="https://colab.research.google.com/github/pritrakholiya2512-pixel/EDUNET_GTU/blob/main/day4-09-07-2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from google.colab import files
uploaded = files.upload()

df = pd.read_csv("RenewableEnergy_Saiful.csv")
print("Dataset Loaded Successfully!")

print("\nFirst 5 Rows")
print(df.head())

print("\nLast 5 Rows")
print(df.tail())

print("\nShape of Dataset")
print(df.shape)

print("\nColumn Names")
print(df.columns)

print("\nInformation")
print(df.info())

print("\nStatistical Summary")
print(df.describe())


## General Analysis ##

# Country
# Represents the name of the country.

# Year
# Shows the year in which renewable energy was recorded.

# Solar_TWh
# Electricity produced from solar energy.

# Wind_TWh
# Electricity produced from wind energy.

# Hydro_TWh
# Electricity produced from hydro energy.

# Total_Renewable_TWh
# Total renewable electricity generated.

## Relationship Between Features ##

# Solar_TWh, Wind_TWh and Hydro_TWh together contribute
# to Total_Renewable_TWh.

# If Solar energy increases,
# Total Renewable Energy also increases.

# If Wind energy increases,
# Total Renewable Energy also increases.

# If Hydro energy increases,
# Total Renewable Energy also increases.

# Different countries produce different amounts
# of renewable energy.

# Year can be used to compare renewable energy growth.

print("\nMissing Values After Handling")
print(df.isnull().sum())

print("\nCorrelation Matrix")
print(df.corr(numeric_only=True))

print("\nAverage Values")
print(df.mean(numeric_only=True))

print("\nMaximum Values")
print(df.max(numeric_only=True))

print("\nMinimum Values")
print(df.min(numeric_only=True))

print("\nNumber of Countries")
print(df["Country"].nunique())

print("\nCountry Names")
print(df["Country"].unique())

print("\nTotal Number of Records")
print(len(df))

print("\nData After Year 2018")
print(df[df["Year"] > 2018])

print("\nDataset Analysis Completed Successfully!")

# SUMMARY:
# 1. Imported pandas and numpy libraries.
# 2. Uploaded the renewable energy dataset in Google Colab.
# 3. Loaded the dataset using pandas.
# 4. Displayed the first and last five rows.
# 5. Checked the shape of the dataset.
# 6. Displayed all column names.
# 7. Checked the data types and basic information.
# 8. Generated statistical summary using describe().
# 9. Analysed every feature of the dataset.
# 10. Explained the relationship between different columns.
# 11. Checked for missing (null) values.
# 12. Handled missing values using mean for numeric columns and "Unknown" for text columns.
# 13. Created a correlation matrix to understand relationships between numeric columns.
# 14. Calculated average, maximum and minimum values.
# 15. Counted the number of unique countries.
# 16. Filtered the dataset based on year.
# 17. Sorted the dataset by Total Renewable Energy.
# 18. Grouped the data by country to calculate average renewable energy production.

# Conclusion:
# This dataset contains renewable energy production information for different countries and years.
# Solar, Wind and Hydro energy contribute to Total Renewable Energy production.
# The dataset was successfully analysed, checked for null values, and prepared for further analysis.
# Out:
#      <input type="file" id="files-62f873d5-5d40-437d-906b-41cd289d16fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62f873d5-5d40-437d-906b-41cd289d16fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
